# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('/content/Employee-turnover (1) (2).xlsx')
df
# Out:
#       Employee Count  Employee ID              Department  \
# 0                  1            1                   Sales
# 1                  1            2  Research & Development
# 2                  1            4  Research & Development
# 3                  1            5  Research & Development
# 4                  1            7  Research & Development
# ...              ...          ...                     ...
# 1465               1         2061  Research & Development
# 1466               1         2062  Research & Development
# 1467               1         2064  Research & Development
# 1468               1         2065                   Sales
# 1469               1         2068  Research & Development
#
#                        Job Role  Gender  Age Marital Status      Education  \
# 0               Sales Executive  Female   41         Single        College
# 1            Research Scientist    Male   49        Married  Below College
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee Count              1470 non-null   int64
#  1   Employee ID                 1470 non-null   int64
#  2   Department                  1470 non-null   object
#  3   Job Role                    1470 non-null   object
#  4   Gender                      1470 non-null   object
#  5   Age                         1470 non-null   int64
#  6   Marital Status              1470 non-null   object
#  7   Education                   1470 non-null   object
#  8   Education Field             1470 non-null   object
#  9   Business Travel             1470 non-null   object
#  10  Distance From Home (kms)    1439 non-null   object
#  11  Job Involvement             1470 non-null   object
#  12  Job Level                   1464 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Employee Count  Employee ID          Age    Job Level  \
# count          1470.0  1470.000000  1470.000000  1464.000000
# mean              1.0  1024.865306    36.923810     2.066940
# std               0.0   602.024335     9.135373     1.107805
# min               1.0     1.000000    18.000000     1.000000
# 25%               1.0   491.250000    30.000000     1.000000
# 50%               1.0  1020.500000    36.000000     2.000000
# 75%               1.0  1555.750000    43.000000     3.000000
# max               1.0  2068.000000    60.000000     5.000000
#
#        Monthly Income (USD)  Salary Hike (%)  Stock Option Level  \
# count           1470.000000      1470.000000         1470.000000
# mean            6502.931293        14.951701            0.793878
# std             4707.956783         3.533904            0.852077
# min             1009.000000        10.000000            0.000000
# 25%             2911.000000        12.000000            0.000000
# ...

# %%
df.null=pd.DataFrame(df.isnull().sum(),columns=["Null Values"])

# %%
df.null
# Out:
#                             Null Values
# Employee Count                        0
# Employee ID                           0
# Department                            0
# Job Role                              0
# Gender                                0
# Age                                   0
# Marital Status                        0
# Education                             0
# Education Field                       0
# Business Travel                       0
# Distance                              0
# Job Involvement                       0
# Job Level                             0
# Job Satisfaction                      0
# Monthly Income (USD)                  0
# Salary Hike (%)                       0
# Stock Option Level                    0
# Over Time                             0
# No. of Companies Worked               0
# Total Working Years                   0
# Years At Company                      0
# Years In Current Role                 0
# ...

# %%
list1=[]
for i in df.null['Null Values']:
  list1.append(i/len(df))
df.null['Ratio']=list1
df.null
# Out:
#                             Null Values  Ratio
# Employee Count                        0    0.0
# Employee ID                           0    0.0
# Department                            0    0.0
# Job Role                              0    0.0
# Gender                                0    0.0
# Age                                   0    0.0
# Marital Status                        0    0.0
# Education                             0    0.0
# Education Field                       0    0.0
# Business Travel                       0    0.0
# Distance                              0    0.0
# Job Involvement                       0    0.0
# Job Level                             0    0.0
# Job Satisfaction                      0    0.0
# Monthly Income (USD)                  0    0.0
# Salary Hike (%)                       0    0.0
# Stock Option Level                    0    0.0
# Over Time                             0    0.0
# No. of Companies Worked               0    0.0
# ...

# %%
df.dropna()
# Out:
#       Employee Count  Employee ID              Department  \
# 427                1          573                   Sales
# 428                1          574  Research & Development
# 429                1          575  Research & Development
# 430                1          577  Research & Development
# 431                1          578  Research & Development
# ...              ...          ...                     ...
# 1465               1         2061  Research & Development
# 1466               1         2062  Research & Development
# 1467               1         2064  Research & Development
# 1468               1         2065                   Sales
# 1469               1         2068  Research & Development
#
#                        Job Role  Gender  Age Marital Status      Education  \
# 427             Sales Executive  Female   60        Married       Bachelor
# 428      Manufacturing Director  Female   47       Divorced        College
# ...

# %%
df.null
# Out:
#                             Null Values  Ratio
# Employee Count                        0    0.0
# Employee ID                           0    0.0
# Department                            0    0.0
# Job Role                              0    0.0
# Gender                                0    0.0
# Age                                   0    0.0
# Marital Status                        0    0.0
# Education                             0    0.0
# Education Field                       0    0.0
# Business Travel                       0    0.0
# Distance                              0    0.0
# Job Involvement                       0    0.0
# Job Level                             0    0.0
# Job Satisfaction                      0    0.0
# Monthly Income (USD)                  0    0.0
# Salary Hike (%)                       0    0.0
# Stock Option Level                    0    0.0
# Over Time                             0    0.0
# No. of Companies Worked               0    0.0
# ...

# %%
df=df.drop(columns=['Training Times Last Year'])

# %%
df.rename(columns={'Distance From Home (kms)':'Distance'},inplace=True)

# %%
df.Distance
# Out:
# 0        1
# 1        8
# 2        2
# 3        3
# 4        2
#         ..
# 1465    23
# 1466     6
# 1467     4
# 1468     2
# 1469     8
# Name: Distance, Length: 1470, dtype: object

# %%
df.Distance.describe()
# Out:
# count     1439
# unique      30
# top          2
# freq       208
# Name: Distance, dtype: int64

# %%
df.Distance.fillna(0,inplace=True)

# %%
df.null
# Out:
#                             Null Values  Ratio
# Employee Count                        0    0.0
# Employee ID                           0    0.0
# Department                            0    0.0
# Job Role                              0    0.0
# Gender                                0    0.0
# Age                                   0    0.0
# Marital Status                        0    0.0
# Education                             0    0.0
# Education Field                       0    0.0
# Business Travel                       0    0.0
# Distance                              0    0.0
# Job Involvement                       0    0.0
# Job Level                             0    0.0
# Job Satisfaction                      0    0.0
# Monthly Income (USD)                  0    0.0
# Salary Hike (%)                       0    0.0
# Stock Option Level                    0    0.0
# Over Time                             0    0.0
# No. of Companies Worked               0    0.0
# ...

# %%
df['Job Level'].describe()
# Out:
# count    1464.000000
# mean        2.066940
# std         1.107805
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: Job Level, dtype: float64

# %%
df['Job Level'].fillna(2,inplace=True)

# %%
df['Job Satisfaction'].describe()
# Out:
# count          1458
# unique            4
# top       Very High
# freq            455
# Name: Job Satisfaction, dtype: object

# %%
df['Job Satisfaction'].value_counts()
# Out:
# Very High    455
# High         437
# Low          288
# Medium       278
# Name: Job Satisfaction, dtype: int64

# %%
df['Job Satisfaction'].fillna('High',inplace=True)

# %%
df.null
# Out:
#                             Null Values  Ratio
# Employee Count                        0    0.0
# Employee ID                           0    0.0
# Department                            0    0.0
# Job Role                              0    0.0
# Gender                                0    0.0
# Age                                   0    0.0
# Marital Status                        0    0.0
# Education                             0    0.0
# Education Field                       0    0.0
# Business Travel                       0    0.0
# Distance                              0    0.0
# Job Involvement                       0    0.0
# Job Level                             0    0.0
# Job Satisfaction                      0    0.0
# Monthly Income (USD)                  0    0.0
# Salary Hike (%)                       0    0.0
# Stock Option Level                    0    0.0
# Over Time                             0    0.0
# No. of Companies Worked               0    0.0
# ...

# %%
df['Total Working Years'].describe()
# Out:
# count    1451.000000
# mean       11.316334
# std         7.786009
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        40.000000
# Name: Total Working Years, dtype: float64

# %%
df['Total Working Years'].fillna(0,inplace=True)

# %%
df.null
# Out:
#                             Null Values  Ratio
# Employee Count                        0    0.0
# Employee ID                           0    0.0
# Department                            0    0.0
# Job Role                              0    0.0
# Gender                                0    0.0
# Age                                   0    0.0
# Marital Status                        0    0.0
# Education                             0    0.0
# Education Field                       0    0.0
# Business Travel                       0    0.0
# Distance                              0    0.0
# Job Involvement                       0    0.0
# Job Level                             0    0.0
# Job Satisfaction                      0    0.0
# Monthly Income (USD)                  0    0.0
# Salary Hike (%)                       0    0.0
# Stock Option Level                    0    0.0
# Over Time                             0    0.0
# No. of Companies Worked               0    0.0
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
corr=df.corr()

# %%
sns.heatmap(corr)

# %%
df['Attrition (Yes/No)'].replace(['Yes','No'],[1,0],inplace=True)

# %%
sns.histplot(data=df,x='Age',bins=[0,20,40,60])
